# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import interact, SelectionSlider

from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import f1_score

#from stumpy import stump, mstump

import lightgbm as lgbm
from lightgbm import LGBMClassifier

import optuna

from preprocessing import create_tensor, agg_over_months, min_max_scaling, standard_scaling
from model_lgbm import train_lgbm, train_best_lgbm, lgbm_plot_evals, lgbm_f1, double_soft_f1_loss
from training import cv_split, study_summary
from utils import save_pred


plt.rcParams["figure.figsize"] = (12, 6)
#np.random.seed(0)

# %% [markdown]
# # Setup

# %%
train_df = pd.read_csv("./data/train.csv", index_col=0).drop_duplicates()
test_df = pd.read_csv("./data/test_nolabels.csv", index_col=0)

class0_idx = train_df.loc[train_df.LABELS == 0].index
class1_idx = train_df.loc[train_df.LABELS == 1].index
y1_weight = train_df.LABELS.sum() / train_df.shape[0]
# y1_weight = 0.6757894386583703

# %%
# Constants to select pandas columns efficiently
# all months abbreviations: jan, feb, mar, etc.
MONTHS = [m.lower() for m in pd.date_range(0, freq="M", periods=12).strftime("%b").to_list()]

# return all columns based on MONTH: train_df[COL_BY_MONTH["jan"]]
COL_BY_MONTH = {}
for month in MONTHS:
    COL_BY_MONTH[month] = [col for col in train_df.columns if month in col]

# all features
FEATURES = [col for col in train_df.columns if col != "LABELS"]
# all features with the month stripped: S2_B2_
COL_BASE = list({col[:-3] for col in FEATURES})
# return all columns based on FEATURE (e.g., across months): train_df[COL_BY_FEATURE["S2_B2_"]]
# alternatively, you can select the same df using: train_df[COL_BY_FEATURE[FEATURES[0]]]
COL_BY_FEATURE = {}
for feature in COL_BASE:
    COL_BY_FEATURE[feature] = [col for col in train_df.columns if feature in col]

# %% [markdown]
# # Preprocessing

# %%
agg_train = agg_over_months(train_df, freq=6)
agg_test = agg_over_months(test_df, freq=6)
scaled_train, scaled_test = standard_scaling(train_df, test_df)

# %%
pca = PCA(n_components = 20)
train_x = scaled_train[[c for c in train_df.columns if c != "LABELS"]]
projected_train = pd.DataFrame(pca.fit_transform(train_x), columns=[f"comp{i}" for i in range(20)])
projected_train[~np.isfinite(projected_train)] = 0
projected_train["LABELS"] = train_df.reset_index().LABELS

# %%
projected_test = pd.DataFrame(pca.transform(test_df), columns=[f"comp{i}" for i in range(20)])
projected_test[~np.isfinite(projected_test)] = 0

# %% [markdown]
# ## optuna optimization

# %%
def objective(trial, train_df):
    # hyperparameter grid for Optuna to explore
    hyperparams = {
        "class_weight": "balanced", 
        "device_type": trial.suggest_categorical("device_type", ["gpu"]),
        # structure
        "max_depth": trial.suggest_int("max_depth", 3, 12, step=1),
        "num_leaves": trial.suggest_int("num_leaves", 20, 3000, step=50),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 200, 10000, step=100),
        # accuracy
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "n_estimators": trial.suggest_categorical("n_estimators", [500]),
        # overfitting
        #"max_bin": trial.suggest_int("max_bin", 200, 300),
        #"lambda_l1": trial.suggest_int("lambda_l1", 0, 100, step=5),
        #"lambda_l2": trial.suggest_int("lambda_l2", 0, 100, step=5),
        "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0, 15),
        #"feature_fraction": trial.suggest_float("feature_fraction", 0.2, 0.95, step=0.1),
    }
    
    # split features and labels
    x_df = train_df.loc[:, ~train_df.columns.isin(["LABELS"])]
    y_df = train_df.loc[:, "LABELS"]
    # create cross-validation folds object
    kfold_cv = StratifiedKFold(n_splits=5, shuffle=True)
    
    # hold the best score of each fold
    cv_scores = []
    for idx, (train_idx, test_idx) in enumerate(kfold_cv.split(x_df, y_df)):
        # train-validation split for each fold
        x_train, x_test = x_df.iloc[train_idx], x_df.iloc[test_idx]
        y_train, y_test = y_df.iloc[train_idx], y_df.iloc[test_idx]
        
        # train classifier with optuna hyperparameters
        clf = LGBMClassifier(objective="binary", **hyperparams)
        clf.fit(
            x_train,
            y_train,
            eval_set=[(x_test, y_test)],
            eval_metric=["logloss", "double_soft_f1_loss"],
        )
        
        # store the best score to the CV score
        best_score = clf.best_score_["valid_0"]["binary_logloss"]#["double_soft_f1_loss"]
        cv_scores.append(best_score)
    
    # return the average best score across CV folds
    return np.mean(cv_scores)

# %%
# create optuna study
study = optuna.create_study(direction="minimize", study_name="lgbm_split")
optimize = lambda trial: objective(trial, projected_train)
# Out:
# [I 2021-12-12 18:07:22,792] A new study created in memory with name: lgbm_split

# %%
# launch optuna study
study.optimize(optimize, n_trials=20)
# Out:
# C:\Users\TJ\miniconda3\envs\kaggle2\lib\site-packages\optuna\distributions.py:560: UserWarning: The distribution is specified by [20, 3000] and step=50, but the range is not divisible by `step`. It will be replaced by [20, 2970].
#   warnings.warn(
# [LightGBM] [Warning] min_data_in_leaf is set=8200, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8200
# [LightGBM] [Warning] min_gain_to_split is set=13.9303815139525, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=13.9303815139525
# [LightGBM] [Warning] lambda_l1 is set=5, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5
# [LightGBM] [Warning] lambda_l2 is set=75, reg_lambda=0.0 will be ignored. Current value: lambda_l2=75
# [1]	valid_0's binary_logloss: 0.67392
# [2]	valid_0's binary_logloss: 0.659291
# [3]	valid_0's binary_logloss: 0.646892
# [4]	valid_0's binary_logloss: 0.638976
# [5]	valid_0's binary_logloss: 0.629919
# [6]	valid_0's binary_logloss: 0.623536
# [7]	valid_0's binary_logloss: 0.61726
# [8]	valid_0's binary_logloss: 0.61138
# [9]	valid_0's binary_logloss: 0.607726
# [10]	valid_0's binary_logloss: 0.604268
# [11]	valid_0's binary_logloss: 0.601178
# [12]	valid_0's binary_logloss: 0.597886
# [13]	valid_0's binary_logloss: 0.595314
# [14]	valid_0's binary_logloss: 0.592528
# [15]	valid_0's binary_logloss: 0.589947
# [16]	valid_0's binary_logloss: 0.588113
# [17]	valid_0's binary_logloss: 0.586483
# [18]	valid_0's binary_logloss: 0.584856
# [19]	valid_0's binary_logloss: 0.583065
# [20]	valid_0's binary_logloss: 0.581261
# [21]	valid_0's binary_logloss: 0.579965
# [22]	valid_0's binary_logloss: 0.578888
# [23]	valid_0's binary_logloss: 0.577389
# [24]	valid_0's binary_logloss: 0.576211
# [25]	valid_0's binary_logloss: 0.574789
# [26]	valid_0's binary_logloss: 0.573275
# [27]	valid_0's binary_logloss: 0.572483
# [28]	valid_0's binary_logloss: 0.571694
# [29]	valid_0's binary_logloss: 0.570711
# [30]	valid_0's binary_logloss: 0.569465
# [31]	valid_0's binary_logloss: 0.568899
# [32]	valid_0's binary_logloss: 0.568308
# [33]	valid_0's binary_logloss: 0.567637
# [34]	valid_0's binary_logloss: 0.567155
# [35]	valid_0's binary_logloss: 0.56622
# [36]	valid_0's binary_logloss: 0.565548
# [37]	valid_0's binary_logloss: 0.564755
# [38]	valid_0's binary_logloss: 0.56432
# [39]	valid_0's binary_logloss: 0.563681
# [40]	valid_0's binary_logloss: 0.563222
# [41]	valid_0's binary_logloss: 0.562796
# [42]	valid_0's binary_logloss: 0.562093
# [43]	valid_0's binary_logloss: 0.561649
# [44]	valid_0's binary_logloss: 0.561198
# [45]	valid_0's binary_logloss: 0.560775
# [46]	valid_0's binary_logloss: 0.560325
# [47]	valid_0's binary_logloss: 0.559816
# [48]	valid_0's binary_logloss: 0.559579
# [49]	valid_0's binary_logloss: 0.559224
# [50]	valid_0's binary_logloss: 0.558876
# [51]	valid_0's binary_logloss: 0.558555
# [52]	valid_0's binary_logloss: 0.558294
# [53]	valid_0's binary_logloss: 0.558084
# [54]	valid_0's binary_logloss: 0.557331
# [55]	valid_0's binary_logloss: 0.556971
# [56]	valid_0's binary_logloss: 0.556548
# [57]	valid_0's binary_logloss: 0.556375
# [58]	valid_0's binary_logloss: 0.556012
# [59]	valid_0's binary_logloss: 0.555861
# [60]	valid_0's binary_logloss: 0.555653
# [61]	valid_0's binary_logloss: 0.555433
# [62]	valid_0's binary_logloss: 0.555197
# [63]	valid_0's binary_logloss: 0.555142
# [64]	valid_0's binary_logloss: 0.555032
# [65]	valid_0's binary_logloss: 0.554969
# [66]	valid_0's binary_logloss: 0.554945
# [67]	valid_0's binary_logloss: 0.554874
# [68]	valid_0's binary_logloss: 0.554874
# [69]	valid_0's binary_logloss: 0.554874
# [70]	valid_0's binary_logloss: 0.554874
# [71]	valid_0's binary_logloss: 0.554874
# [72]	valid_0's binary_logloss: 0.554874
# [73]	valid_0's binary_logloss: 0.554874
# [74]	valid_0's binary_logloss: 0.554874
# [75]	valid_0's binary_logloss: 0.554874
# [76]	valid_0's binary_logloss: 0.554874
# [77]	valid_0's binary_logloss: 0.554874
# [78]	valid_0's binary_logloss: 0.554874
# [79]	valid_0's binary_logloss: 0.554874
# [80]	valid_0's binary_logloss: 0.554874
# [81]	valid_0's binary_logloss: 0.554874
# [82]	valid_0's binary_logloss: 0.554874
# [83]	valid_0's binary_logloss: 0.554874
# [84]	valid_0's binary_logloss: 0.554874
# [85]	valid_0's binary_logloss: 0.554874
# [86]	valid_0's binary_logloss: 0.554874
# [87]	valid_0's binary_logloss: 0.554874
# [88]	valid_0's binary_logloss: 0.554874
# [89]	valid_0's binary_logloss: 0.554874
# [90]	valid_0's binary_logloss: 0.554874
# [91]	valid_0's binary_logloss: 0.554874
# [92]	valid_0's binary_logloss: 0.554874
# [93]	valid_0's binary_logloss: 0.554874
# [94]	valid_0's binary_logloss: 0.554874
# [95]	valid_0's binary_logloss: 0.554874
# [96]	valid_0's binary_logloss: 0.554874
# [97]	valid_0's binary_logloss: 0.554874
# [98]	valid_0's binary_logloss: 0.554874
# [99]	valid_0's binary_logloss: 0.554874
# [100]	valid_0's binary_logloss: 0.554874
# [101]	valid_0's binary_logloss: 0.554874
# [102]	valid_0's binary_logloss: 0.554874
# [103]	valid_0's binary_logloss: 0.554874
# [104]	valid_0's binary_logloss: 0.554874
# [105]	valid_0's binary_logloss: 0.554874
# [106]	valid_0's binary_logloss: 0.554874
# [107]	valid_0's binary_logloss: 0.554874
# [108]	valid_0's binary_logloss: 0.554874
# [109]	valid_0's binary_logloss: 0.554874
# [110]	valid_0's binary_logloss: 0.554874
# [111]	valid_0's binary_logloss: 0.554874
# [112]	valid_0's binary_logloss: 0.554874
# [113]	valid_0's binary_logloss: 0.554874
# [114]	valid_0's binary_logloss: 0.554874
# [115]	valid_0's binary_logloss: 0.554874
# [116]	valid_0's binary_logloss: 0.554874
# [117]	valid_0's binary_logloss: 0.554874
# [118]	valid_0's binary_logloss: 0.554874
# [119]	valid_0's binary_logloss: 0.554874
# [120]	valid_0's binary_logloss: 0.554874
# [121]	valid_0's binary_logloss: 0.554874
# [122]	valid_0's binary_logloss: 0.554874
# [123]	valid_0's binary_logloss: 0.554874
# [124]	valid_0's binary_logloss: 0.554874
# [125]	valid_0's binary_logloss: 0.554874
# [126]	valid_0's binary_logloss: 0.554874
# [127]	valid_0's binary_logloss: 0.554874
# [128]	valid_0's binary_logloss: 0.554874
# [129]	valid_0's binary_logloss: 0.554874
# [130]	valid_0's binary_logloss: 0.554874
# [131]	valid_0's binary_logloss: 0.554874
# [132]	valid_0's binary_logloss: 0.554874
# [133]	valid_0's binary_logloss: 0.554874
# [134]	valid_0's binary_logloss: 0.554874
# [135]	valid_0's binary_logloss: 0.554874
# [136]	valid_0's binary_logloss: 0.554874
# [137]	valid_0's binary_logloss: 0.554874
# [138]	valid_0's binary_logloss: 0.554874
# [139]	valid_0's binary_logloss: 0.554874
# [140]	valid_0's binary_logloss: 0.554874
# [141]	valid_0's binary_logloss: 0.554874
# [142]	valid_0's binary_logloss: 0.554874
# [143]	valid_0's binary_logloss: 0.554874
# [144]	valid_0's binary_logloss: 0.554874
# [145]	valid_0's binary_logloss: 0.554874
# [146]	valid_0's binary_logloss: 0.554874
# [147]	valid_0's binary_logloss: 0.554874
# [148]	valid_0's binary_logloss: 0.554874
# [149]	valid_0's binary_logloss: 0.554874
# [150]	valid_0's binary_logloss: 0.554874
# [151]	valid_0's binary_logloss: 0.554874
# [152]	valid_0's binary_logloss: 0.554874
# [153]	valid_0's binary_logloss: 0.554874
# [154]	valid_0's binary_logloss: 0.554874
# [155]	valid_0's binary_logloss: 0.554874
# [156]	valid_0's binary_logloss: 0.554874
# [157]	valid_0's binary_logloss: 0.554874
# [158]	valid_0's binary_logloss: 0.554874
# [159]	valid_0's binary_logloss: 0.554874
# [160]	valid_0's binary_logloss: 0.554874
# [161]	valid_0's binary_logloss: 0.554874
# [162]	valid_0's binary_logloss: 0.554874
# [163]	valid_0's binary_logloss: 0.554874
# [164]	valid_0's binary_logloss: 0.554874
# [165]	valid_0's binary_logloss: 0.554874
# [166]	valid_0's binary_logloss: 0.554874
# [167]	valid_0's binary_logloss: 0.554874
# [168]	valid_0's binary_logloss: 0.554874
# [169]	valid_0's binary_logloss: 0.554874
# [170]	valid_0's binary_logloss: 0.554874
# [171]	valid_0's binary_logloss: 0.554874
# [172]	valid_0's binary_logloss: 0.554874
# [173]	valid_0's binary_logloss: 0.554874
# [174]	valid_0's binary_logloss: 0.554874
# [175]	valid_0's binary_logloss: 0.554874
# [176]	valid_0's binary_logloss: 0.554874
# [177]	valid_0's binary_logloss: 0.554874
# [178]	valid_0's binary_logloss: 0.554874
# [179]	valid_0's binary_logloss: 0.554874
# [180]	valid_0's binary_logloss: 0.554874
# [181]	valid_0's binary_logloss: 0.554874
# [182]	valid_0's binary_logloss: 0.554874
# [183]	valid_0's binary_logloss: 0.554874
# [184]	valid_0's binary_logloss: 0.554874
# [185]	valid_0's binary_logloss: 0.554874
# [186]	valid_0's binary_logloss: 0.554874
# [187]	valid_0's binary_logloss: 0.554874
# [188]	valid_0's binary_logloss: 0.554874
# [189]	valid_0's binary_logloss: 0.554874
# [190]	valid_0's binary_logloss: 0.554874
# [191]	valid_0's binary_logloss: 0.554874
# [192]	valid_0's binary_logloss: 0.554874
# [193]	valid_0's binary_logloss: 0.554874
# [194]	valid_0's binary_logloss: 0.554874
# [195]	valid_0's binary_logloss: 0.554874
# [196]	valid_0's binary_logloss: 0.554874
# [197]	valid_0's binary_logloss: 0.554874
# [198]	valid_0's binary_logloss: 0.554874
# [199]	valid_0's binary_logloss: 0.554874
# [200]	valid_0's binary_logloss: 0.554874
# [201]	valid_0's binary_logloss: 0.554874
# [202]	valid_0's binary_logloss: 0.554874
# [203]	valid_0's binary_logloss: 0.554874
# [204]	valid_0's binary_logloss: 0.554874
# [205]	valid_0's binary_logloss: 0.554874
# [206]	valid_0's binary_logloss: 0.554874
# [207]	valid_0's binary_logloss: 0.554874
# [208]	valid_0's binary_logloss: 0.554874
# [209]	valid_0's binary_logloss: 0.554874
# [210]	valid_0's binary_logloss: 0.554874
# [211]	valid_0's binary_logloss: 0.554874
# [212]	valid_0's binary_logloss: 0.554874
# [213]	valid_0's binary_logloss: 0.554874
# [214]	valid_0's binary_logloss: 0.554874
# [215]	valid_0's binary_logloss: 0.554874
# [216]	valid_0's binary_logloss: 0.554874
# [217]	valid_0's binary_logloss: 0.554874
# [218]	valid_0's binary_logloss: 0.554874
# [219]	valid_0's binary_logloss: 0.554874
# [220]	valid_0's binary_logloss: 0.554874
# [221]	valid_0's binary_logloss: 0.554874
# [222]	valid_0's binary_logloss: 0.554874
# [223]	valid_0's binary_logloss: 0.554874
# [224]	valid_0's binary_logloss: 0.554874
# [225]	valid_0's binary_logloss: 0.554874
# [226]	valid_0's binary_logloss: 0.554874
# [227]	valid_0's binary_logloss: 0.554874
# [228]	valid_0's binary_logloss: 0.554874
# [229]	valid_0's binary_logloss: 0.554874
# [230]	valid_0's binary_logloss: 0.554874
# [231]	valid_0's binary_logloss: 0.554874
# [232]	valid_0's binary_logloss: 0.554874
# [233]	valid_0's binary_logloss: 0.554874
# [234]	valid_0's binary_logloss: 0.554874
# [235]	valid_0's binary_logloss: 0.554874
# [236]	valid_0's binary_logloss: 0.554874
# [237]	valid_0's binary_logloss: 0.554874
# [238]	valid_0's binary_logloss: 0.554874
# [239]	valid_0's binary_logloss: 0.554874
# [240]	valid_0's binary_logloss: 0.554874
# [241]	valid_0's binary_logloss: 0.554874
# [242]	valid_0's binary_logloss: 0.554874
# [243]	valid_0's binary_logloss: 0.554874
# [244]	valid_0's binary_logloss: 0.554874
# [245]	valid_0's binary_logloss: 0.554874
# [246]	valid_0's binary_logloss: 0.554874
# [247]	valid_0's binary_logloss: 0.554874
# [248]	valid_0's binary_logloss: 0.554874
# [249]	valid_0's binary_logloss: 0.554874
# [250]	valid_0's binary_logloss: 0.554874
# [251]	valid_0's binary_logloss: 0.554874
# [252]	valid_0's binary_logloss: 0.554874
# [253]	valid_0's binary_logloss: 0.554874
# [254]	valid_0's binary_logloss: 0.554874
# [255]	valid_0's binary_logloss: 0.554874
# [256]	valid_0's binary_logloss: 0.554874
# [257]	valid_0's binary_logloss: 0.554874
# [258]	valid_0's binary_logloss: 0.554874
# [259]	valid_0's binary_logloss: 0.554874
# [260]	valid_0's binary_logloss: 0.554874
# [261]	valid_0's binary_logloss: 0.554874
# [262]	valid_0's binary_logloss: 0.554874
# [263]	valid_0's binary_logloss: 0.554874
# [264]	valid_0's binary_logloss: 0.554874
# [265]	valid_0's binary_logloss: 0.554874
# [266]	valid_0's binary_logloss: 0.554874
# [267]	valid_0's binary_logloss: 0.554874
# [268]	valid_0's binary_logloss: 0.554874
# [269]	valid_0's binary_logloss: 0.554874
# [270]	valid_0's binary_logloss: 0.554874
# [271]	valid_0's binary_logloss: 0.554874
# [272]	valid_0's binary_logloss: 0.554874
# [273]	valid_0's binary_logloss: 0.554874
# [274]	valid_0's binary_logloss: 0.554874
# [275]	valid_0's binary_logloss: 0.554874
# [276]	valid_0's binary_logloss: 0.554874
# [277]	valid_0's binary_logloss: 0.554874
# [278]	valid_0's binary_logloss: 0.554874
# [279]	valid_0's binary_logloss: 0.554874
# [280]	valid_0's binary_logloss: 0.554874
# [281]	valid_0's binary_logloss: 0.554874
# [282]	valid_0's binary_logloss: 0.554874
# [283]	valid_0's binary_logloss: 0.554874
# [284]	valid_0's binary_logloss: 0.554874
# [285]	valid_0's binary_logloss: 0.554874
# [286]	valid_0's binary_logloss: 0.554874
# [287]	valid_0's binary_logloss: 0.554874
# [288]	valid_0's binary_logloss: 0.554874
# [289]	valid_0's binary_logloss: 0.554874
# [290]	valid_0's binary_logloss: 0.554874
# [291]	valid_0's binary_logloss: 0.554874
# [292]	valid_0's binary_logloss: 0.554874
# [293]	valid_0's binary_logloss: 0.554874
# [294]	valid_0's binary_logloss: 0.554874
# [295]	valid_0's binary_logloss: 0.554874
# [296]	valid_0's binary_logloss: 0.554874
# [297]	valid_0's binary_logloss: 0.554874
# [298]	valid_0's binary_logloss: 0.554874
# [299]	valid_0's binary_logloss: 0.554874
# [300]	valid_0's binary_logloss: 0.554874
# [301]	valid_0's binary_logloss: 0.554874
# [302]	valid_0's binary_logloss: 0.554874
# [303]	valid_0's binary_logloss: 0.554874
# [304]	valid_0's binary_logloss: 0.554874
# [305]	valid_0's binary_logloss: 0.554874
# [306]	valid_0's binary_logloss: 0.554874
# [307]	valid_0's binary_logloss: 0.554874
# [308]	valid_0's binary_logloss: 0.554874
# [309]	valid_0's binary_logloss: 0.554874
# [310]	valid_0's binary_logloss: 0.554874
# [311]	valid_0's binary_logloss: 0.554874
# [312]	valid_0's binary_logloss: 0.554874
# [313]	valid_0's binary_logloss: 0.554874
# [314]	valid_0's binary_logloss: 0.554874
# [315]	valid_0's binary_logloss: 0.554874
# [316]	valid_0's binary_logloss: 0.554874
# [317]	valid_0's binary_logloss: 0.554874
# [318]	valid_0's binary_logloss: 0.554874
# [319]	valid_0's binary_logloss: 0.554874
# [320]	valid_0's binary_logloss: 0.554874
# [321]	valid_0's binary_logloss: 0.554874
# [322]	valid_0's binary_logloss: 0.554874
# [323]	valid_0's binary_logloss: 0.554874
# [324]	valid_0's binary_logloss: 0.554874
# [325]	valid_0's binary_logloss: 0.554874
# [326]	valid_0's binary_logloss: 0.554874
# [327]	valid_0's binary_logloss: 0.554874
# [328]	valid_0's binary_logloss: 0.554874
# [329]	valid_0's binary_logloss: 0.554874
# [330]	valid_0's binary_logloss: 0.554874
# [331]	valid_0's binary_logloss: 0.554874
# [332]	valid_0's binary_logloss: 0.554874
# [333]	valid_0's binary_logloss: 0.554874
# [334]	valid_0's binary_logloss: 0.554874
# [335]	valid_0's binary_logloss: 0.554874
# [336]	valid_0's binary_logloss: 0.554874
# [337]	valid_0's binary_logloss: 0.554874
# [338]	valid_0's binary_logloss: 0.554874
# [339]	valid_0's binary_logloss: 0.554874
# [340]	valid_0's binary_logloss: 0.554874
# [341]	valid_0's binary_logloss: 0.554874
# [342]	valid_0's binary_logloss: 0.554874
# [343]	valid_0's binary_logloss: 0.554874
# [344]	valid_0's binary_logloss: 0.554874
# [345]	valid_0's binary_logloss: 0.554874
# [346]	valid_0's binary_logloss: 0.554874
# [347]	valid_0's binary_logloss: 0.554874
# [348]	valid_0's binary_logloss: 0.554874
# [349]	valid_0's binary_logloss: 0.554874
# [350]	valid_0's binary_logloss: 0.554874
# [351]	valid_0's binary_logloss: 0.554874
# [352]	valid_0's binary_logloss: 0.554874
# [353]	valid_0's binary_logloss: 0.554874
# [354]	valid_0's binary_logloss: 0.554874
# [355]	valid_0's binary_logloss: 0.554874
# [356]	valid_0's binary_logloss: 0.554874
# [357]	valid_0's binary_logloss: 0.554874
# [358]	valid_0's binary_logloss: 0.554874
# [359]	valid_0's binary_logloss: 0.554874
# [360]	valid_0's binary_logloss: 0.554874
# [361]	valid_0's binary_logloss: 0.554874
# [362]	valid_0's binary_logloss: 0.554874
# [363]	valid_0's binary_logloss: 0.554874
# [364]	valid_0's binary_logloss: 0.554874
# [365]	valid_0's binary_logloss: 0.554874
# [366]	valid_0's binary_logloss: 0.554874
# [367]	valid_0's binary_logloss: 0.554874
# [368]	valid_0's binary_logloss: 0.554874
# [369]	valid_0's binary_logloss: 0.554874
# [370]	valid_0's binary_logloss: 0.554874
# [371]	valid_0's binary_logloss: 0.554874
# [372]	valid_0's binary_logloss: 0.554874
# [373]	valid_0's binary_logloss: 0.554874
# [374]	valid_0's binary_logloss: 0.554874
# [375]	valid_0's binary_logloss: 0.554874
# [376]	valid_0's binary_logloss: 0.554874
# [377]	valid_0's binary_logloss: 0.554874
# [378]	valid_0's binary_logloss: 0.554874
# [379]	valid_0's binary_logloss: 0.554874
# [380]	valid_0's binary_logloss: 0.554874
# [381]	valid_0's binary_logloss: 0.554874
# [382]	valid_0's binary_logloss: 0.554874
# [383]	valid_0's binary_logloss: 0.554874
# [384]	valid_0's binary_logloss: 0.554874
# [385]	valid_0's binary_logloss: 0.554874
# [386]	valid_0's binary_logloss: 0.554874
# [387]	valid_0's binary_logloss: 0.554874
# [388]	valid_0's binary_logloss: 0.554874
# [389]	valid_0's binary_logloss: 0.554874
# [390]	valid_0's binary_logloss: 0.554874
# [391]	valid_0's binary_logloss: 0.554874
# [392]	valid_0's binary_logloss: 0.554874
# [393]	valid_0's binary_logloss: 0.554874
# [394]	valid_0's binary_logloss: 0.554874
# [395]	valid_0's binary_logloss: 0.554874
# [396]	valid_0's binary_logloss: 0.554874
# [397]	valid_0's binary_logloss: 0.554874
# [398]	valid_0's binary_logloss: 0.554874
# [399]	valid_0's binary_logloss: 0.554874
# [400]	valid_0's binary_logloss: 0.554874
# [401]	valid_0's binary_logloss: 0.554874
# [402]	valid_0's binary_logloss: 0.554874
# [403]	valid_0's binary_logloss: 0.554874
# [404]	valid_0's binary_logloss: 0.554874
# [405]	valid_0's binary_logloss: 0.554874
# [406]	valid_0's binary_logloss: 0.554874
# [407]	valid_0's binary_logloss: 0.554874
# [408]	valid_0's binary_logloss: 0.554874
# [409]	valid_0's binary_logloss: 0.554874
# [410]	valid_0's binary_logloss: 0.554874
# [411]	valid_0's binary_logloss: 0.554874
# [412]	valid_0's binary_logloss: 0.554874
# [413]	valid_0's binary_logloss: 0.554874
# [414]	valid_0's binary_logloss: 0.554874
# [415]	valid_0's binary_logloss: 0.554874
# [416]	valid_0's binary_logloss: 0.554874
# [417]	valid_0's binary_logloss: 0.554874
# [418]	valid_0's binary_logloss: 0.554874
# [419]	valid_0's binary_logloss: 0.554874
# [420]	valid_0's binary_logloss: 0.554874
# [421]	valid_0's binary_logloss: 0.554874
# [422]	valid_0's binary_logloss: 0.554874
# [423]	valid_0's binary_logloss: 0.554874
# [424]	valid_0's binary_logloss: 0.554874
# [425]	valid_0's binary_logloss: 0.554874
# [426]	valid_0's binary_logloss: 0.554874
# [427]	valid_0's binary_logloss: 0.554874
# [428]	valid_0's binary_logloss: 0.554874
# [429]	valid_0's binary_logloss: 0.554874
# [430]	valid_0's binary_logloss: 0.554874
# [431]	valid_0's binary_logloss: 0.554874
# [432]	valid_0's binary_logloss: 0.554874
# [433]	valid_0's binary_logloss: 0.554874
# [434]	valid_0's binary_logloss: 0.554874
# [435]	valid_0's binary_logloss: 0.554874
# [436]	valid_0's binary_logloss: 0.554874
# [437]	valid_0's binary_logloss: 0.554874
# [438]	valid_0's binary_logloss: 0.554874
# [439]	valid_0's binary_logloss: 0.554874
# [440]	valid_0's binary_logloss: 0.554874
# [441]	valid_0's binary_logloss: 0.554874
# [442]	valid_0's binary_logloss: 0.554874
# [443]	valid_0's binary_logloss: 0.554874
# [444]	valid_0's binary_logloss: 0.554874
# [445]	valid_0's binary_logloss: 0.554874
# [446]	valid_0's binary_logloss: 0.554874
# [447]	valid_0's binary_logloss: 0.554874
# [448]	valid_0's binary_logloss: 0.554874
# [449]	valid_0's binary_logloss: 0.554874
# [450]	valid_0's binary_logloss: 0.554874
# [451]	valid_0's binary_logloss: 0.554874
# [452]	valid_0's binary_logloss: 0.554874
# [453]	valid_0's binary_logloss: 0.554874
# [454]	valid_0's binary_logloss: 0.554874
# [455]	valid_0's binary_logloss: 0.554874
# [456]	valid_0's binary_logloss: 0.554874
# [457]	valid_0's binary_logloss: 0.554874
# [458]	valid_0's binary_logloss: 0.554874
# [459]	valid_0's binary_logloss: 0.554874
# [460]	valid_0's binary_logloss: 0.554874
# [461]	valid_0's binary_logloss: 0.554874
# [462]	valid_0's binary_logloss: 0.554874
# [463]	valid_0's binary_logloss: 0.554874
# [464]	valid_0's binary_logloss: 0.554874
# [465]	valid_0's binary_logloss: 0.554874
# [466]	valid_0's binary_logloss: 0.554874
# [467]	valid_0's binary_logloss: 0.554874
# [468]	valid_0's binary_logloss: 0.554874
# [469]	valid_0's binary_logloss: 0.554874
# [470]	valid_0's binary_logloss: 0.554874
# [471]	valid_0's binary_logloss: 0.554874
# [472]	valid_0's binary_logloss: 0.554874
# [473]	valid_0's binary_logloss: 0.554874
# [474]	valid_0's binary_logloss: 0.554874
# [475]	valid_0's binary_logloss: 0.554874
# [476]	valid_0's binary_logloss: 0.554874
# [477]	valid_0's binary_logloss: 0.554874
# [478]	valid_0's binary_logloss: 0.554874
# [479]	valid_0's binary_logloss: 0.554874
# [480]	valid_0's binary_logloss: 0.554874
# [481]	valid_0's binary_logloss: 0.554874
# [482]	valid_0's binary_logloss: 0.554874
# [483]	valid_0's binary_logloss: 0.554874
# [484]	valid_0's binary_logloss: 0.554874
# [485]	valid_0's binary_logloss: 0.554874
# [486]	valid_0's binary_logloss: 0.554874
# [487]	valid_0's binary_logloss: 0.554874
# [488]	valid_0's binary_logloss: 0.554874
# [489]	valid_0's binary_logloss: 0.554874
# [490]	valid_0's binary_logloss: 0.554874
# [491]	valid_0's binary_logloss: 0.554874
# [492]	valid_0's binary_logloss: 0.554874
# [493]	valid_0's binary_logloss: 0.554874
# [494]	valid_0's binary_logloss: 0.554874
# [495]	valid_0's binary_logloss: 0.554874
# [496]	valid_0's binary_logloss: 0.554874
# [497]	valid_0's binary_logloss: 0.554874
# [498]	valid_0's binary_logloss: 0.554874
# [499]	valid_0's binary_logloss: 0.554874
# [500]	valid_0's binary_logloss: 0.554874
# [1]	valid_0's binary_logloss: 0.673965
# [2]	valid_0's binary_logloss: 0.660677
# [3]	valid_0's binary_logloss: 0.64808
# [4]	valid_0's binary_logloss: 0.638085
# [5]	valid_0's binary_logloss: 0.630832
# [6]	valid_0's binary_logloss: 0.624165
# [7]	valid_0's binary_logloss: 0.619486
# [8]	valid_0's binary_logloss: 0.614559
# [9]	valid_0's binary_logloss: 0.609391
# [10]	valid_0's binary_logloss: 0.606521
# [11]	valid_0's binary_logloss: 0.603343
# [12]	valid_0's binary_logloss: 0.600523
# [13]	valid_0's binary_logloss: 0.597384
# [14]	valid_0's binary_logloss: 0.595078
# [15]	valid_0's binary_logloss: 0.592876
# [16]	valid_0's binary_logloss: 0.590585
# [17]	valid_0's binary_logloss: 0.588947
# [18]	valid_0's binary_logloss: 0.586948
# [19]	valid_0's binary_logloss: 0.585147
# [20]	valid_0's binary_logloss: 0.584005
# [21]	valid_0's binary_logloss: 0.58271
# [22]	valid_0's binary_logloss: 0.581119
# [23]	valid_0's binary_logloss: 0.579937
# [24]	valid_0's binary_logloss: 0.578835
# [25]	valid_0's binary_logloss: 0.577902
# [26]	valid_0's binary_logloss: 0.57677
# [27]	valid_0's binary_logloss: 0.576022
# [28]	valid_0's binary_logloss: 0.575045
# [29]	valid_0's binary_logloss: 0.573816
# [30]	valid_0's binary_logloss: 0.572901
# [31]	valid_0's binary_logloss: 0.572262
# [32]	valid_0's binary_logloss: 0.571895
# [33]	valid_0's binary_logloss: 0.571017
# [34]	valid_0's binary_logloss: 0.57038
# [35]	valid_0's binary_logloss: 0.56994
# [36]	valid_0's binary_logloss: 0.569098
# [37]	valid_0's binary_logloss: 0.568452
# [38]	valid_0's binary_logloss: 0.568103
# [39]	valid_0's binary_logloss: 0.567278
# [40]	valid_0's binary_logloss: 0.566835
# [41]	valid_0's binary_logloss: 0.566375
# [42]	valid_0's binary_logloss: 0.566054
# [43]	valid_0's binary_logloss: 0.565797
# [44]	valid_0's binary_logloss: 0.565383
# [45]	valid_0's binary_logloss: 0.56495
# [46]	valid_0's binary_logloss: 0.564304
# [47]	valid_0's binary_logloss: 0.563779
# [48]	valid_0's binary_logloss: 0.563383
# [49]	valid_0's binary_logloss: 0.562774
# [50]	valid_0's binary_logloss: 0.56229
# [51]	valid_0's binary_logloss: 0.562013
# [52]	valid_0's binary_logloss: 0.561631
# [53]	valid_0's binary_logloss: 0.561389
# [54]	valid_0's binary_logloss: 0.561103
# [55]	valid_0's binary_logloss: 0.560425
# [56]	valid_0's binary_logloss: 0.560177
# [57]	valid_0's binary_logloss: 0.56008
# [58]	valid_0's binary_logloss: 0.55998
# [59]	valid_0's binary_logloss: 0.559673
# [60]	valid_0's binary_logloss: 0.559499
# [61]	valid_0's binary_logloss: 0.559187
# [62]	valid_0's binary_logloss: 0.55859
# [63]	valid_0's binary_logloss: 0.558295
# [64]	valid_0's binary_logloss: 0.558032
# [65]	valid_0's binary_logloss: 0.557727
# [66]	valid_0's binary_logloss: 0.557388
# [67]	valid_0's binary_logloss: 0.557341
# [68]	valid_0's binary_logloss: 0.55715
# [69]	valid_0's binary_logloss: 0.557103
# [70]	valid_0's binary_logloss: 0.557103
# [71]	valid_0's binary_logloss: 0.557103
# [72]	valid_0's binary_logloss: 0.557103
# [73]	valid_0's binary_logloss: 0.557103
# [74]	valid_0's binary_logloss: 0.557103
# [75]	valid_0's binary_logloss: 0.557103
# [76]	valid_0's binary_logloss: 0.557103
# [77]	valid_0's binary_logloss: 0.557103
# [78]	valid_0's binary_logloss: 0.557103
# [79]	valid_0's binary_logloss: 0.557103
# [80]	valid_0's binary_logloss: 0.557103
# [81]	valid_0's binary_logloss: 0.557103
# [82]	valid_0's binary_logloss: 0.557103
# [83]	valid_0's binary_logloss: 0.557103
# [84]	valid_0's binary_logloss: 0.557103
# [85]	valid_0's binary_logloss: 0.557103
# [86]	valid_0's binary_logloss: 0.557103
# [87]	valid_0's binary_logloss: 0.557103
# [88]	valid_0's binary_logloss: 0.557103
# [89]	valid_0's binary_logloss: 0.557103
# [90]	valid_0's binary_logloss: 0.557103
# [91]	valid_0's binary_logloss: 0.557103
# [92]	valid_0's binary_logloss: 0.557103
# [93]	valid_0's binary_logloss: 0.557103
# [94]	valid_0's binary_logloss: 0.557103
# [95]	valid_0's binary_logloss: 0.557103
# [96]	valid_0's binary_logloss: 0.557103
# [97]	valid_0's binary_logloss: 0.557103
# [98]	valid_0's binary_logloss: 0.557103
# [99]	valid_0's binary_logloss: 0.557103
# [100]	valid_0's binary_logloss: 0.557103
# [101]	valid_0's binary_logloss: 0.557103
# [102]	valid_0's binary_logloss: 0.557103
# [103]	valid_0's binary_logloss: 0.557103
# [104]	valid_0's binary_logloss: 0.557103
# [105]	valid_0's binary_logloss: 0.557103
# [106]	valid_0's binary_logloss: 0.557103
# [107]	valid_0's binary_logloss: 0.557103
# [108]	valid_0's binary_logloss: 0.557103
# [109]	valid_0's binary_logloss: 0.557103
# [110]	valid_0's binary_logloss: 0.557103
# [111]	valid_0's binary_logloss: 0.557103
# [112]	valid_0's binary_logloss: 0.557103
# [113]	valid_0's binary_logloss: 0.557103
# [114]	valid_0's binary_logloss: 0.557103
# [115]	valid_0's binary_logloss: 0.557103
# [116]	valid_0's binary_logloss: 0.557103
# [117]	valid_0's binary_logloss: 0.557103
# [118]	valid_0's binary_logloss: 0.557103
# [119]	valid_0's binary_logloss: 0.557103
# [120]	valid_0's binary_logloss: 0.557103
# [121]	valid_0's binary_logloss: 0.557103
# [122]	valid_0's binary_logloss: 0.557103
# [123]	valid_0's binary_logloss: 0.557103
# [124]	valid_0's binary_logloss: 0.557103
# [125]	valid_0's binary_logloss: 0.557103
# [126]	valid_0's binary_logloss: 0.557103
# [127]	valid_0's binary_logloss: 0.557103
# [128]	valid_0's binary_logloss: 0.557103
# [129]	valid_0's binary_logloss: 0.557103
# [130]	valid_0's binary_logloss: 0.557103
# [131]	valid_0's binary_logloss: 0.557103
# [132]	valid_0's binary_logloss: 0.557103
# [133]	valid_0's binary_logloss: 0.557103
# [134]	valid_0's binary_logloss: 0.557103
# [135]	valid_0's binary_logloss: 0.557103
# [136]	valid_0's binary_logloss: 0.557103
# [137]	valid_0's binary_logloss: 0.557103
# [138]	valid_0's binary_logloss: 0.557103
# [139]	valid_0's binary_logloss: 0.557103
# [140]	valid_0's binary_logloss: 0.557103
# [141]	valid_0's binary_logloss: 0.557103
# [142]	valid_0's binary_logloss: 0.557103
# [143]	valid_0's binary_logloss: 0.557103
# [144]	valid_0's binary_logloss: 0.557103
# [145]	valid_0's binary_logloss: 0.557103
# [146]	valid_0's binary_logloss: 0.557103
# [147]	valid_0's binary_logloss: 0.557103
# [148]	valid_0's binary_logloss: 0.557103
# [149]	valid_0's binary_logloss: 0.557103
# [150]	valid_0's binary_logloss: 0.557103
# [151]	valid_0's binary_logloss: 0.557103
# [152]	valid_0's binary_logloss: 0.557103
# [153]	valid_0's binary_logloss: 0.557103
# [154]	valid_0's binary_logloss: 0.557103
# [155]	valid_0's binary_logloss: 0.557103
# [156]	valid_0's binary_logloss: 0.557103
# [157]	valid_0's binary_logloss: 0.557103
# [158]	valid_0's binary_logloss: 0.557103
# [159]	valid_0's binary_logloss: 0.557103
# [160]	valid_0's binary_logloss: 0.557103
# [161]	valid_0's binary_logloss: 0.557103
# [162]	valid_0's binary_logloss: 0.557103
# [163]	valid_0's binary_logloss: 0.557103
# [164]	valid_0's binary_logloss: 0.557103
# [165]	valid_0's binary_logloss: 0.557103
# [166]	valid_0's binary_logloss: 0.557103
# [167]	valid_0's binary_logloss: 0.557103
# [168]	valid_0's binary_logloss: 0.557103
# [169]	valid_0's binary_logloss: 0.557103
# [170]	valid_0's binary_logloss: 0.557103
# [171]	valid_0's binary_logloss: 0.557103
# [172]	valid_0's binary_logloss: 0.557103
# [173]	valid_0's binary_logloss: 0.557103
# [174]	valid_0's binary_logloss: 0.557103
# [175]	valid_0's binary_logloss: 0.557103
# [176]	valid_0's binary_logloss: 0.557103
# [177]	valid_0's binary_logloss: 0.557103
# [178]	valid_0's binary_logloss: 0.557103
# [179]	valid_0's binary_logloss: 0.557103
# [180]	valid_0's binary_logloss: 0.557103
# [181]	valid_0's binary_logloss: 0.557103
# [182]	valid_0's binary_logloss: 0.557103
# [183]	valid_0's binary_logloss: 0.557103
# [184]	valid_0's binary_logloss: 0.557103
# [185]	valid_0's binary_logloss: 0.557103
# [186]	valid_0's binary_logloss: 0.557103
# [187]	valid_0's binary_logloss: 0.557103
# [188]	valid_0's binary_logloss: 0.557103
# [189]	valid_0's binary_logloss: 0.557103
# [190]	valid_0's binary_logloss: 0.557103
# [191]	valid_0's binary_logloss: 0.557103
# [192]	valid_0's binary_logloss: 0.557103
# [193]	valid_0's binary_logloss: 0.557103
# [194]	valid_0's binary_logloss: 0.557103
# [195]	valid_0's binary_logloss: 0.557103
# [196]	valid_0's binary_logloss: 0.557103
# [197]	valid_0's binary_logloss: 0.557103
# [198]	valid_0's binary_logloss: 0.557103
# [199]	valid_0's binary_logloss: 0.557103
# [200]	valid_0's binary_logloss: 0.557103
# [201]	valid_0's binary_logloss: 0.557103
# [202]	valid_0's binary_logloss: 0.557103
# [203]	valid_0's binary_logloss: 0.557103
# [204]	valid_0's binary_logloss: 0.557103
# [205]	valid_0's binary_logloss: 0.557103
# [206]	valid_0's binary_logloss: 0.557103
# [207]	valid_0's binary_logloss: 0.557103
# [208]	valid_0's binary_logloss: 0.557103
# [209]	valid_0's binary_logloss: 0.557103
# [210]	valid_0's binary_logloss: 0.557103
# [211]	valid_0's binary_logloss: 0.557103
# [212]	valid_0's binary_logloss: 0.557103
# [213]	valid_0's binary_logloss: 0.557103
# [214]	valid_0's binary_logloss: 0.557103
# [215]	valid_0's binary_logloss: 0.557103
# [216]	valid_0's binary_logloss: 0.557103
# [217]	valid_0's binary_logloss: 0.557103
# [218]	valid_0's binary_logloss: 0.557103
# [219]	valid_0's binary_logloss: 0.557103
# [220]	valid_0's binary_logloss: 0.557103
# [221]	valid_0's binary_logloss: 0.557103
# [222]	valid_0's binary_logloss: 0.557103
# [223]	valid_0's binary_logloss: 0.557103
# [224]	valid_0's binary_logloss: 0.557103
# [225]	valid_0's binary_logloss: 0.557103
# [226]	valid_0's binary_logloss: 0.557103
# [227]	valid_0's binary_logloss: 0.557103
# [228]	valid_0's binary_logloss: 0.557103
# [229]	valid_0's binary_logloss: 0.557103
# [230]	valid_0's binary_logloss: 0.557103
# [231]	valid_0's binary_logloss: 0.557103
# [232]	valid_0's binary_logloss: 0.557103
# [233]	valid_0's binary_logloss: 0.557103
# [234]	valid_0's binary_logloss: 0.557103
# [235]	valid_0's binary_logloss: 0.557103
# [236]	valid_0's binary_logloss: 0.557103
# [237]	valid_0's binary_logloss: 0.557103
# [238]	valid_0's binary_logloss: 0.557103
# [239]	valid_0's binary_logloss: 0.557103
# [240]	valid_0's binary_logloss: 0.557103
# [241]	valid_0's binary_logloss: 0.557103
# [242]	valid_0's binary_logloss: 0.557103
# [243]	valid_0's binary_logloss: 0.557103
# [244]	valid_0's binary_logloss: 0.557103
# [245]	valid_0's binary_logloss: 0.557103
# [246]	valid_0's binary_logloss: 0.557103
# [247]	valid_0's binary_logloss: 0.557103
# [248]	valid_0's binary_logloss: 0.557103
# [249]	valid_0's binary_logloss: 0.557103
# [250]	valid_0's binary_logloss: 0.557103
# [251]	valid_0's binary_logloss: 0.557103
# [252]	valid_0's binary_logloss: 0.557103
# [253]	valid_0's binary_logloss: 0.557103
# [254]	valid_0's binary_logloss: 0.557103
# [255]	valid_0's binary_logloss: 0.557103
# [256]	valid_0's binary_logloss: 0.557103
# [257]	valid_0's binary_logloss: 0.557103
# [258]	valid_0's binary_logloss: 0.557103
# [259]	valid_0's binary_logloss: 0.557103
# [260]	valid_0's binary_logloss: 0.557103
# [261]	valid_0's binary_logloss: 0.557103
# [262]	valid_0's binary_logloss: 0.557103
# [263]	valid_0's binary_logloss: 0.557103
# [264]	valid_0's binary_logloss: 0.557103
# [265]	valid_0's binary_logloss: 0.557103
# [266]	valid_0's binary_logloss: 0.557103
# [267]	valid_0's binary_logloss: 0.557103
# [268]	valid_0's binary_logloss: 0.557103
# [269]	valid_0's binary_logloss: 0.557103
# [270]	valid_0's binary_logloss: 0.557103
# [271]	valid_0's binary_logloss: 0.557103
# [272]	valid_0's binary_logloss: 0.557103
# [273]	valid_0's binary_logloss: 0.557103
# [274]	valid_0's binary_logloss: 0.557103
# [275]	valid_0's binary_logloss: 0.557103
# [276]	valid_0's binary_logloss: 0.557103
# [277]	valid_0's binary_logloss: 0.557103
# [278]	valid_0's binary_logloss: 0.557103
# [279]	valid_0's binary_logloss: 0.557103
# [280]	valid_0's binary_logloss: 0.557103
# [281]	valid_0's binary_logloss: 0.557103
# [282]	valid_0's binary_logloss: 0.557103
# [283]	valid_0's binary_logloss: 0.557103
# [284]	valid_0's binary_logloss: 0.557103
# [285]	valid_0's binary_logloss: 0.557103
# [286]	valid_0's binary_logloss: 0.557103
# [287]	valid_0's binary_logloss: 0.557103
# [288]	valid_0's binary_logloss: 0.557103
# [289]	valid_0's binary_logloss: 0.557103
# [290]	valid_0's binary_logloss: 0.557103
# [291]	valid_0's binary_logloss: 0.557103
# [292]	valid_0's binary_logloss: 0.557103
# [293]	valid_0's binary_logloss: 0.557103
# [294]	valid_0's binary_logloss: 0.557103
# [295]	valid_0's binary_logloss: 0.557103
# [296]	valid_0's binary_logloss: 0.557103
# [297]	valid_0's binary_logloss: 0.557103
# [298]	valid_0's binary_logloss: 0.557103
# [299]	valid_0's binary_logloss: 0.557103
# [300]	valid_0's binary_logloss: 0.557103
# [301]	valid_0's binary_logloss: 0.557103
# [302]	valid_0's binary_logloss: 0.557103
# [303]	valid_0's binary_logloss: 0.557103
# [304]	valid_0's binary_logloss: 0.557103
# [305]	valid_0's binary_logloss: 0.557103
# [306]	valid_0's binary_logloss: 0.557103
# [307]	valid_0's binary_logloss: 0.557103
# [308]	valid_0's binary_logloss: 0.557103
# [309]	valid_0's binary_logloss: 0.557103
# [310]	valid_0's binary_logloss: 0.557103
# [311]	valid_0's binary_logloss: 0.557103
# [312]	valid_0's binary_logloss: 0.557103
# [313]	valid_0's binary_logloss: 0.557103
# [314]	valid_0's binary_logloss: 0.557103
# [315]	valid_0's binary_logloss: 0.557103
# [316]	valid_0's binary_logloss: 0.557103
# [317]	valid_0's binary_logloss: 0.557103
# [318]	valid_0's binary_logloss: 0.557103
# [319]	valid_0's binary_logloss: 0.557103
# [320]	valid_0's binary_logloss: 0.557103
# [321]	valid_0's binary_logloss: 0.557103
# [322]	valid_0's binary_logloss: 0.557103
# [323]	valid_0's binary_logloss: 0.557103
# [324]	valid_0's binary_logloss: 0.557103
# [325]	valid_0's binary_logloss: 0.557103
# [326]	valid_0's binary_logloss: 0.557103
# [327]	valid_0's binary_logloss: 0.557103
# [328]	valid_0's binary_logloss: 0.557103
# [329]	valid_0's binary_logloss: 0.557103
# [330]	valid_0's binary_logloss: 0.557103
# [331]	valid_0's binary_logloss: 0.557103
# [332]	valid_0's binary_logloss: 0.557103
# [333]	valid_0's binary_logloss: 0.557103
# [334]	valid_0's binary_logloss: 0.557103
# [335]	valid_0's binary_logloss: 0.557103
# [336]	valid_0's binary_logloss: 0.557103
# [337]	valid_0's binary_logloss: 0.557103
# [338]	valid_0's binary_logloss: 0.557103
# [339]	valid_0's binary_logloss: 0.557103
# [340]	valid_0's binary_logloss: 0.557103
# [341]	valid_0's binary_logloss: 0.557103
# [342]	valid_0's binary_logloss: 0.557103
# [343]	valid_0's binary_logloss: 0.557103
# [344]	valid_0's binary_logloss: 0.557103
# [345]	valid_0's binary_logloss: 0.557103
# [346]	valid_0's binary_logloss: 0.557103
# [347]	valid_0's binary_logloss: 0.557103
# [348]	valid_0's binary_logloss: 0.557103
# [349]	valid_0's binary_logloss: 0.557103
# [350]	valid_0's binary_logloss: 0.557103
# [351]	valid_0's binary_logloss: 0.557103
# [352]	valid_0's binary_logloss: 0.557103
# [353]	valid_0's binary_logloss: 0.557103
# [354]	valid_0's binary_logloss: 0.557103
# [355]	valid_0's binary_logloss: 0.557103
# [356]	valid_0's binary_logloss: 0.557103
# [357]	valid_0's binary_logloss: 0.557103
# [358]	valid_0's binary_logloss: 0.557103
# [359]	valid_0's binary_logloss: 0.557103
# [360]	valid_0's binary_logloss: 0.557103
# [361]	valid_0's binary_logloss: 0.557103
# [362]	valid_0's binary_logloss: 0.557103
# [363]	valid_0's binary_logloss: 0.557103
# [364]	valid_0's binary_logloss: 0.557103
# [365]	valid_0's binary_logloss: 0.557103
# [366]	valid_0's binary_logloss: 0.557103
# [367]	valid_0's binary_logloss: 0.557103
# [368]	valid_0's binary_logloss: 0.557103
# [369]	valid_0's binary_logloss: 0.557103
# [370]	valid_0's binary_logloss: 0.557103
# [371]	valid_0's binary_logloss: 0.557103
# [372]	valid_0's binary_logloss: 0.557103
# [373]	valid_0's binary_logloss: 0.557103
# [374]	valid_0's binary_logloss: 0.557103
# [375]	valid_0's binary_logloss: 0.557103
# [376]	valid_0's binary_logloss: 0.557103
# [377]	valid_0's binary_logloss: 0.557103
# [378]	valid_0's binary_logloss: 0.557103
# [379]	valid_0's binary_logloss: 0.557103
# [380]	valid_0's binary_logloss: 0.557103
# [381]	valid_0's binary_logloss: 0.557103
# [382]	valid_0's binary_logloss: 0.557103
# [383]	valid_0's binary_logloss: 0.557103
# [384]	valid_0's binary_logloss: 0.557103
# [385]	valid_0's binary_logloss: 0.557103
# [386]	valid_0's binary_logloss: 0.557103
# [387]	valid_0's binary_logloss: 0.557103
# [388]	valid_0's binary_logloss: 0.557103
# [389]	valid_0's binary_logloss: 0.557103
# [390]	valid_0's binary_logloss: 0.557103
# [391]	valid_0's binary_logloss: 0.557103
# [392]	valid_0's binary_logloss: 0.557103
# [393]	valid_0's binary_logloss: 0.557103
# [394]	valid_0's binary_logloss: 0.557103
# [395]	valid_0's binary_logloss: 0.557103
# [396]	valid_0's binary_logloss: 0.557103
# [397]	valid_0's binary_logloss: 0.557103
# [398]	valid_0's binary_logloss: 0.557103
# [399]	valid_0's binary_logloss: 0.557103
# [400]	valid_0's binary_logloss: 0.557103
# [401]	valid_0's binary_logloss: 0.557103
# [402]	valid_0's binary_logloss: 0.557103
# [403]	valid_0's binary_logloss: 0.557103
# [404]	valid_0's binary_logloss: 0.557103
# [405]	valid_0's binary_logloss: 0.557103
# [406]	valid_0's binary_logloss: 0.557103
# [407]	valid_0's binary_logloss: 0.557103
# [408]	valid_0's binary_logloss: 0.557103
# [409]	valid_0's binary_logloss: 0.557103
# [410]	valid_0's binary_logloss: 0.557103
# [411]	valid_0's binary_logloss: 0.557103
# [412]	valid_0's binary_logloss: 0.557103
# [413]	valid_0's binary_logloss: 0.557103
# [414]	valid_0's binary_logloss: 0.557103
# [415]	valid_0's binary_logloss: 0.557103
# [416]	valid_0's binary_logloss: 0.557103
# [417]	valid_0's binary_logloss: 0.557103
# [418]	valid_0's binary_logloss: 0.557103
# [419]	valid_0's binary_logloss: 0.557103
# [420]	valid_0's binary_logloss: 0.557103
# [421]	valid_0's binary_logloss: 0.557103
# [422]	valid_0's binary_logloss: 0.557103
# [423]	valid_0's binary_logloss: 0.557103
# [424]	valid_0's binary_logloss: 0.557103
# [425]	valid_0's binary_logloss: 0.557103
# [426]	valid_0's binary_logloss: 0.557103
# [427]	valid_0's binary_logloss: 0.557103
# [428]	valid_0's binary_logloss: 0.557103
# [429]	valid_0's binary_logloss: 0.557103
# [430]	valid_0's binary_logloss: 0.557103
# [431]	valid_0's binary_logloss: 0.557103
# [432]	valid_0's binary_logloss: 0.557103
# [433]	valid_0's binary_logloss: 0.557103
# [434]	valid_0's binary_logloss: 0.557103
# [435]	valid_0's binary_logloss: 0.557103
# [436]	valid_0's binary_logloss: 0.557103
# [437]	valid_0's binary_logloss: 0.557103
# [438]	valid_0's binary_logloss: 0.557103
# [439]	valid_0's binary_logloss: 0.557103
# [440]	valid_0's binary_logloss: 0.557103
# [441]	valid_0's binary_logloss: 0.557103
# [442]	valid_0's binary_logloss: 0.557103
# [443]	valid_0's binary_logloss: 0.557103
# [444]	valid_0's binary_logloss: 0.557103
# [445]	valid_0's binary_logloss: 0.557103
# [446]	valid_0's binary_logloss: 0.557103
# [447]	valid_0's binary_logloss: 0.557103
# [448]	valid_0's binary_logloss: 0.557103
# [449]	valid_0's binary_logloss: 0.557103
# [450]	valid_0's binary_logloss: 0.557103
# [451]	valid_0's binary_logloss: 0.557103
# [452]	valid_0's binary_logloss: 0.557103
# [453]	valid_0's binary_logloss: 0.557103
# [454]	valid_0's binary_logloss: 0.557103
# [455]	valid_0's binary_logloss: 0.557103
# [456]	valid_0's binary_logloss: 0.557103
# [457]	valid_0's binary_logloss: 0.557103
# [458]	valid_0's binary_logloss: 0.557103
# [459]	valid_0's binary_logloss: 0.557103
# [460]	valid_0's binary_logloss: 0.557103
# [461]	valid_0's binary_logloss: 0.557103
# [462]	valid_0's binary_logloss: 0.557103
# [463]	valid_0's binary_logloss: 0.557103
# [464]	valid_0's binary_logloss: 0.557103
# [465]	valid_0's binary_logloss: 0.557103
# [466]	valid_0's binary_logloss: 0.557103
# [467]	valid_0's binary_logloss: 0.557103
# [468]	valid_0's binary_logloss: 0.557103
# [469]	valid_0's binary_logloss: 0.557103
# [470]	valid_0's binary_logloss: 0.557103
# [471]	valid_0's binary_logloss: 0.557103
# [472]	valid_0's binary_logloss: 0.557103
# [473]	valid_0's binary_logloss: 0.557103
# [474]	valid_0's binary_logloss: 0.557103
# [475]	valid_0's binary_logloss: 0.557103
# [476]	valid_0's binary_logloss: 0.557103
# [477]	valid_0's binary_logloss: 0.557103
# [478]	valid_0's binary_logloss: 0.557103
# [479]	valid_0's binary_logloss: 0.557103
# [480]	valid_0's binary_logloss: 0.557103
# [481]	valid_0's binary_logloss: 0.557103
# [482]	valid_0's binary_logloss: 0.557103
# [483]	valid_0's binary_logloss: 0.557103
# [484]	valid_0's binary_logloss: 0.557103
# [485]	valid_0's binary_logloss: 0.557103
# [486]	valid_0's binary_logloss: 0.557103
# [487]	valid_0's binary_logloss: 0.557103
# [488]	valid_0's binary_logloss: 0.557103
# [489]	valid_0's binary_logloss: 0.557103
# [490]	valid_0's binary_logloss: 0.557103
# [491]	valid_0's binary_logloss: 0.557103
# [492]	valid_0's binary_logloss: 0.557103
# [493]	valid_0's binary_logloss: 0.557103
# [494]	valid_0's binary_logloss: 0.557103
# [495]	valid_0's binary_logloss: 0.557103
# [496]	valid_0's binary_logloss: 0.557103
# [497]	valid_0's binary_logloss: 0.557103
# [498]	valid_0's binary_logloss: 0.557103
# [499]	valid_0's binary_logloss: 0.557103
# [500]	valid_0's binary_logloss: 0.557103
# [1]	valid_0's binary_logloss: 0.673391
# [2]	valid_0's binary_logloss: 0.658226
# [3]	valid_0's binary_logloss: 0.646933
# [4]	valid_0's binary_logloss: 0.636332
# [5]	valid_0's binary_logloss: 0.629328
# [6]	valid_0's binary_logloss: 0.621865
# [7]	valid_0's binary_logloss: 0.616781
# [8]	valid_0's binary_logloss: 0.612073
# [9]	valid_0's binary_logloss: 0.606415
# [10]	valid_0's binary_logloss: 0.602404
# [11]	valid_0's binary_logloss: 0.598911
# [12]	valid_0's binary_logloss: 0.595432
# [13]	valid_0's binary_logloss: 0.592804
# [14]	valid_0's binary_logloss: 0.590507
# [15]	valid_0's binary_logloss: 0.588726
# [16]	valid_0's binary_logloss: 0.586609
# [17]	valid_0's binary_logloss: 0.584584
# [18]	valid_0's binary_logloss: 0.5828
# [19]	valid_0's binary_logloss: 0.581127
# [20]	valid_0's binary_logloss: 0.579961
# [21]	valid_0's binary_logloss: 0.578417
# [22]	valid_0's binary_logloss: 0.577257
# [23]	valid_0's binary_logloss: 0.576018
# [24]	valid_0's binary_logloss: 0.574759
# [25]	valid_0's binary_logloss: 0.573602
# [26]	valid_0's binary_logloss: 0.572691
# [27]	valid_0's binary_logloss: 0.571538
# [28]	valid_0's binary_logloss: 0.570415
# [29]	valid_0's binary_logloss: 0.569573
# [30]	valid_0's binary_logloss: 0.56851
# [31]	valid_0's binary_logloss: 0.567556
# [32]	valid_0's binary_logloss: 0.56687
# [33]	valid_0's binary_logloss: 0.566267
# [34]	valid_0's binary_logloss: 0.565372
# [35]	valid_0's binary_logloss: 0.56468
# [36]	valid_0's binary_logloss: 0.564266
# [37]	valid_0's binary_logloss: 0.56331
# [38]	valid_0's binary_logloss: 0.562685
# [39]	valid_0's binary_logloss: 0.561939
# [40]	valid_0's binary_logloss: 0.561421
# [41]	valid_0's binary_logloss: 0.561012
# [42]	valid_0's binary_logloss: 0.560509
# [43]	valid_0's binary_logloss: 0.560143
# [44]	valid_0's binary_logloss: 0.559393
# [45]	valid_0's binary_logloss: 0.558879
# [46]	valid_0's binary_logloss: 0.558457
# [47]	valid_0's binary_logloss: 0.558256
# [48]	valid_0's binary_logloss: 0.557949
# [49]	valid_0's binary_logloss: 0.557476
# [50]	valid_0's binary_logloss: 0.55711
# [51]	valid_0's binary_logloss: 0.556984
# [52]	valid_0's binary_logloss: 0.556604
# [53]	valid_0's binary_logloss: 0.556325
# [54]	valid_0's binary_logloss: 0.556102
# [55]	valid_0's binary_logloss: 0.555628
# [56]	valid_0's binary_logloss: 0.555482
# [57]	valid_0's binary_logloss: 0.555162
# [58]	valid_0's binary_logloss: 0.554914
# [59]	valid_0's binary_logloss: 0.554607
# [60]	valid_0's binary_logloss: 0.55446
# [61]	valid_0's binary_logloss: 0.554278
# [62]	valid_0's binary_logloss: 0.55395
# [63]	valid_0's binary_logloss: 0.553612
# [64]	valid_0's binary_logloss: 0.553586
# [65]	valid_0's binary_logloss: 0.553134
# [66]	valid_0's binary_logloss: 0.552849
# [67]	valid_0's binary_logloss: 0.552601
# [68]	valid_0's binary_logloss: 0.552286
# [69]	valid_0's binary_logloss: 0.552091
# [70]	valid_0's binary_logloss: 0.551986
# [71]	valid_0's binary_logloss: 0.551869
# [72]	valid_0's binary_logloss: 0.551748
# [73]	valid_0's binary_logloss: 0.551595
# [74]	valid_0's binary_logloss: 0.551558
# [75]	valid_0's binary_logloss: 0.551529
# [76]	valid_0's binary_logloss: 0.551529
# [77]	valid_0's binary_logloss: 0.551529
# [78]	valid_0's binary_logloss: 0.551529
# [79]	valid_0's binary_logloss: 0.551529
# [80]	valid_0's binary_logloss: 0.551529
# [81]	valid_0's binary_logloss: 0.551529
# [82]	valid_0's binary_logloss: 0.551529
# [83]	valid_0's binary_logloss: 0.551529
# [84]	valid_0's binary_logloss: 0.551529
# [85]	valid_0's binary_logloss: 0.551529
# [86]	valid_0's binary_logloss: 0.551529
# [87]	valid_0's binary_logloss: 0.551529
# [88]	valid_0's binary_logloss: 0.551529
# [89]	valid_0's binary_logloss: 0.551529
# [90]	valid_0's binary_logloss: 0.551529
# [91]	valid_0's binary_logloss: 0.551529
# [92]	valid_0's binary_logloss: 0.551529
# [93]	valid_0's binary_logloss: 0.551529
# [94]	valid_0's binary_logloss: 0.551529
# [95]	valid_0's binary_logloss: 0.551529
# [96]	valid_0's binary_logloss: 0.551529
# [97]	valid_0's binary_logloss: 0.551529
# [98]	valid_0's binary_logloss: 0.551529
# [99]	valid_0's binary_logloss: 0.551529
# [100]	valid_0's binary_logloss: 0.551529
# [101]	valid_0's binary_logloss: 0.551529
# [102]	valid_0's binary_logloss: 0.551529
# [103]	valid_0's binary_logloss: 0.551529
# [104]	valid_0's binary_logloss: 0.551529
# [105]	valid_0's binary_logloss: 0.551529
# [106]	valid_0's binary_logloss: 0.551529
# [107]	valid_0's binary_logloss: 0.551529
# [108]	valid_0's binary_logloss: 0.551529
# [109]	valid_0's binary_logloss: 0.551529
# [110]	valid_0's binary_logloss: 0.551529
# [111]	valid_0's binary_logloss: 0.551529
# [112]	valid_0's binary_logloss: 0.551529
# [113]	valid_0's binary_logloss: 0.551529
# [114]	valid_0's binary_logloss: 0.551529
# [115]	valid_0's binary_logloss: 0.551529
# [116]	valid_0's binary_logloss: 0.551529
# [117]	valid_0's binary_logloss: 0.551529
# [118]	valid_0's binary_logloss: 0.551529
# [119]	valid_0's binary_logloss: 0.551529
# [120]	valid_0's binary_logloss: 0.551529
# [121]	valid_0's binary_logloss: 0.551529
# [122]	valid_0's binary_logloss: 0.551529
# [123]	valid_0's binary_logloss: 0.551529
# [124]	valid_0's binary_logloss: 0.551529
# [125]	valid_0's binary_logloss: 0.551529
# [126]	valid_0's binary_logloss: 0.551529
# [127]	valid_0's binary_logloss: 0.551529
# [128]	valid_0's binary_logloss: 0.551529
# [129]	valid_0's binary_logloss: 0.551529
# [130]	valid_0's binary_logloss: 0.551529
# [131]	valid_0's binary_logloss: 0.551529
# [132]	valid_0's binary_logloss: 0.551529
# [133]	valid_0's binary_logloss: 0.551529
# [134]	valid_0's binary_logloss: 0.551529
# [135]	valid_0's binary_logloss: 0.551529
# [136]	valid_0's binary_logloss: 0.551529
# [137]	valid_0's binary_logloss: 0.551529
# [138]	valid_0's binary_logloss: 0.551529
# [139]	valid_0's binary_logloss: 0.551529
# [140]	valid_0's binary_logloss: 0.551529
# [141]	valid_0's binary_logloss: 0.551529
# [142]	valid_0's binary_logloss: 0.551529
# [143]	valid_0's binary_logloss: 0.551529
# [144]	valid_0's binary_logloss: 0.551529
# [145]	valid_0's binary_logloss: 0.551529
# [146]	valid_0's binary_logloss: 0.551529
# [147]	valid_0's binary_logloss: 0.551529
# [148]	valid_0's binary_logloss: 0.551529
# [149]	valid_0's binary_logloss: 0.551529
# [150]	valid_0's binary_logloss: 0.551529
# [151]	valid_0's binary_logloss: 0.551529
# [152]	valid_0's binary_logloss: 0.551529
# [153]	valid_0's binary_logloss: 0.551529
# [154]	valid_0's binary_logloss: 0.551529
# [155]	valid_0's binary_logloss: 0.551529
# [156]	valid_0's binary_logloss: 0.551529
# [157]	valid_0's binary_logloss: 0.551529
# [158]	valid_0's binary_logloss: 0.551529
# [159]	valid_0's binary_logloss: 0.551529
# [160]	valid_0's binary_logloss: 0.551529
# [161]	valid_0's binary_logloss: 0.551529
# ...
# [119]	valid_0's binary_logloss: 0.582579
# [120]	valid_0's binary_logloss: 0.582199
# [121]	valid_0's binary_logloss: 0.581876
# [122]	valid_0's binary_logloss: 0.581507
# [123]	valid_0's binary_logloss: 0.581133
# [124]	valid_0's binary_logloss: 0.580774
# [125]	valid_0's binary_logloss: 0.580467
# [126]	valid_0's binary_logloss: 0.580089
# [127]	valid_0's binary_logloss: 0.579731
# [128]	valid_0's binary_logloss: 0.579389
# [129]	valid_0's binary_logloss: 0.579092
# [130]	valid_0's binary_logloss: 0.57874
# [131]	valid_0's binary_logloss: 0.578391
# [132]	valid_0's binary_logloss: 0.578049
# [133]	valid_0's binary_logloss: 0.577751
# [134]	valid_0's binary_logloss: 0.577347
# [135]	valid_0's binary_logloss: 0.577045
# [136]	valid_0's binary_logloss: 0.576652
# [137]	valid_0's binary_logloss: 0.576301
# [138]	valid_0's binary_logloss: 0.575989
# [139]	valid_0's binary_logloss: 0.57561
# [140]	valid_0's binary_logloss: 0.575327
# [141]	valid_0's binary_logloss: 0.574972
# [142]	valid_0's binary_logloss: 0.574668
# [143]	valid_0's binary_logloss: 0.574337
# [144]	valid_0's binary_logloss: 0.574021
# [145]	valid_0's binary_logloss: 0.573763
# [146]	valid_0's binary_logloss: 0.573424
# [147]	valid_0's binary_logloss: 0.573118
# [148]	valid_0's binary_logloss: 0.572833
# [149]	valid_0's binary_logloss: 0.572489
# [150]	valid_0's binary_logloss: 0.572148
# [151]	valid_0's binary_logloss: 0.571813
# [152]	valid_0's binary_logloss: 0.571523
# [153]	valid_0's binary_logloss: 0.571191
# [154]	valid_0's binary_logloss: 0.570902
# [155]	valid_0's binary_logloss: 0.570589
# [156]	valid_0's binary_logloss: 0.570272
# [157]	valid_0's binary_logloss: 0.569956
# [158]	valid_0's binary_logloss: 0.569678
# [159]	valid_0's binary_logloss: 0.569372
# [160]	valid_0's binary_logloss: 0.569123
# [161]	valid_0's binary_logloss: 0.568831
# [162]	valid_0's binary_logloss: 0.568535
# [163]	valid_0's binary_logloss: 0.568254
# [164]	valid_0's binary_logloss: 0.567971
# [165]	valid_0's binary_logloss: 0.567723
# [166]	valid_0's binary_logloss: 0.567479
# [167]	valid_0's binary_logloss: 0.567196
# [168]	valid_0's binary_logloss: 0.566929
# [169]	valid_0's binary_logloss: 0.566691
# [170]	valid_0's binary_logloss: 0.566421
# [171]	valid_0's binary_logloss: 0.566159
# [172]	valid_0's binary_logloss: 0.565893
# [173]	valid_0's binary_logloss: 0.565668
# [174]	valid_0's binary_logloss: 0.565419
# [175]	valid_0's binary_logloss: 0.565156
# [176]	valid_0's binary_logloss: 0.564902
# [177]	valid_0's binary_logloss: 0.564676
# [178]	valid_0's binary_logloss: 0.564429
# [179]	valid_0's binary_logloss: 0.564218
# [180]	valid_0's binary_logloss: 0.563971
# [181]	valid_0's binary_logloss: 0.563733
# [182]	valid_0's binary_logloss: 0.563517
# [183]	valid_0's binary_logloss: 0.563283
# [184]	valid_0's binary_logloss: 0.563045
# [185]	valid_0's binary_logloss: 0.562828
# [186]	valid_0's binary_logloss: 0.562591
# [187]	valid_0's binary_logloss: 0.562378
# [188]	valid_0's binary_logloss: 0.562148
# [189]	valid_0's binary_logloss: 0.561946
# [190]	valid_0's binary_logloss: 0.561723
# [191]	valid_0's binary_logloss: 0.561488
# [192]	valid_0's binary_logloss: 0.561266
# [193]	valid_0's binary_logloss: 0.561032
# [194]	valid_0's binary_logloss: 0.560818
# [195]	valid_0's binary_logloss: 0.560604
# [196]	valid_0's binary_logloss: 0.560388
# [197]	valid_0's binary_logloss: 0.560179
# [198]	valid_0's binary_logloss: 0.559985
# [199]	valid_0's binary_logloss: 0.559746
# [200]	valid_0's binary_logloss: 0.559543
# [201]	valid_0's binary_logloss: 0.559338
# [202]	valid_0's binary_logloss: 0.559123
# [203]	valid_0's binary_logloss: 0.558878
# [204]	valid_0's binary_logloss: 0.558684
# [205]	valid_0's binary_logloss: 0.558457
# [206]	valid_0's binary_logloss: 0.558255
# [207]	valid_0's binary_logloss: 0.558059
# [208]	valid_0's binary_logloss: 0.55788
# [209]	valid_0's binary_logloss: 0.557646
# [210]	valid_0's binary_logloss: 0.557467
# [211]	valid_0's binary_logloss: 0.557279
# [212]	valid_0's binary_logloss: 0.557104
# [213]	valid_0's binary_logloss: 0.556943
# [214]	valid_0's binary_logloss: 0.556713
# [215]	valid_0's binary_logloss: 0.556535
# [216]	valid_0's binary_logloss: 0.556358
# [217]	valid_0's binary_logloss: 0.556164
# [218]	valid_0's binary_logloss: 0.555968
# [219]	valid_0's binary_logloss: 0.55576
# [220]	valid_0's binary_logloss: 0.55554
# [221]	valid_0's binary_logloss: 0.555402
# [222]	valid_0's binary_logloss: 0.555224
# [223]	valid_0's binary_logloss: 0.55503
# [224]	valid_0's binary_logloss: 0.554826
# [225]	valid_0's binary_logloss: 0.55464
# [226]	valid_0's binary_logloss: 0.554426
# [227]	valid_0's binary_logloss: 0.554256
# [228]	valid_0's binary_logloss: 0.55406
# [229]	valid_0's binary_logloss: 0.553846
# [230]	valid_0's binary_logloss: 0.553687
# [231]	valid_0's binary_logloss: 0.553483
# [232]	valid_0's binary_logloss: 0.553302
# [233]	valid_0's binary_logloss: 0.553133
# [234]	valid_0's binary_logloss: 0.552932
# [235]	valid_0's binary_logloss: 0.552768
# [236]	valid_0's binary_logloss: 0.552612
# [237]	valid_0's binary_logloss: 0.552454
# [238]	valid_0's binary_logloss: 0.552264
# [239]	valid_0's binary_logloss: 0.552113
# [240]	valid_0's binary_logloss: 0.551936
# [241]	valid_0's binary_logloss: 0.551768
# [242]	valid_0's binary_logloss: 0.551621
# [243]	valid_0's binary_logloss: 0.551449
# [244]	valid_0's binary_logloss: 0.551274
# [245]	valid_0's binary_logloss: 0.551139
# [246]	valid_0's binary_logloss: 0.550998
# [247]	valid_0's binary_logloss: 0.550835
# [248]	valid_0's binary_logloss: 0.550665
# [249]	valid_0's binary_logloss: 0.550497
# [250]	valid_0's binary_logloss: 0.550366
# [251]	valid_0's binary_logloss: 0.550192
# [252]	valid_0's binary_logloss: 0.550059
# [253]	valid_0's binary_logloss: 0.549856
# [254]	valid_0's binary_logloss: 0.549703
# [255]	valid_0's binary_logloss: 0.549553
# [256]	valid_0's binary_logloss: 0.549372
# [257]	valid_0's binary_logloss: 0.549183
# [258]	valid_0's binary_logloss: 0.549027
# [259]	valid_0's binary_logloss: 0.54888
# [260]	valid_0's binary_logloss: 0.54874
# [261]	valid_0's binary_logloss: 0.548622
# [262]	valid_0's binary_logloss: 0.54844
# [263]	valid_0's binary_logloss: 0.548302
# [264]	valid_0's binary_logloss: 0.548173
# [265]	valid_0's binary_logloss: 0.548002
# [266]	valid_0's binary_logloss: 0.54786
# [267]	valid_0's binary_logloss: 0.547685
# [268]	valid_0's binary_logloss: 0.547541
# [269]	valid_0's binary_logloss: 0.547411
# [270]	valid_0's binary_logloss: 0.54728
# [271]	valid_0's binary_logloss: 0.547095
# [272]	valid_0's binary_logloss: 0.546956
# [273]	valid_0's binary_logloss: 0.546823
# [274]	valid_0's binary_logloss: 0.546687
# [275]	valid_0's binary_logloss: 0.546569
# [276]	valid_0's binary_logloss: 0.546389
# [277]	valid_0's binary_logloss: 0.546256
# [278]	valid_0's binary_logloss: 0.54609
# [279]	valid_0's binary_logloss: 0.545914
# [280]	valid_0's binary_logloss: 0.545804
# [281]	valid_0's binary_logloss: 0.545685
# [282]	valid_0's binary_logloss: 0.545579
# [283]	valid_0's binary_logloss: 0.545456
# [284]	valid_0's binary_logloss: 0.54534
# [285]	valid_0's binary_logloss: 0.54518
# [286]	valid_0's binary_logloss: 0.545072
# [287]	valid_0's binary_logloss: 0.544949
# [288]	valid_0's binary_logloss: 0.54479
# [289]	valid_0's binary_logloss: 0.544693
# [290]	valid_0's binary_logloss: 0.544544
# [291]	valid_0's binary_logloss: 0.544439
# [292]	valid_0's binary_logloss: 0.544343
# [293]	valid_0's binary_logloss: 0.544189
# [294]	valid_0's binary_logloss: 0.544057
# [295]	valid_0's binary_logloss: 0.543966
# [296]	valid_0's binary_logloss: 0.543864
# [297]	valid_0's binary_logloss: 0.543765
# [298]	valid_0's binary_logloss: 0.543651
# [299]	valid_0's binary_logloss: 0.54352
# [300]	valid_0's binary_logloss: 0.543389
# [301]	valid_0's binary_logloss: 0.543311
# [302]	valid_0's binary_logloss: 0.543152
# [303]	valid_0's binary_logloss: 0.543002
# [304]	valid_0's binary_logloss: 0.542892
# [305]	valid_0's binary_logloss: 0.542749
# [306]	valid_0's binary_logloss: 0.54266
# [307]	valid_0's binary_logloss: 0.542535
# [308]	valid_0's binary_logloss: 0.542452
# [309]	valid_0's binary_logloss: 0.542333
# [310]	valid_0's binary_logloss: 0.542216
# [311]	valid_0's binary_logloss: 0.542144
# [312]	valid_0's binary_logloss: 0.542026
# [313]	valid_0's binary_logloss: 0.541903
# [314]	valid_0's binary_logloss: 0.541816
# [315]	valid_0's binary_logloss: 0.541703
# [316]	valid_0's binary_logloss: 0.541589
# [317]	valid_0's binary_logloss: 0.541494
# [318]	valid_0's binary_logloss: 0.541426
# [319]	valid_0's binary_logloss: 0.541294
# [320]	valid_0's binary_logloss: 0.541196
# [321]	valid_0's binary_logloss: 0.541078
# [322]	valid_0's binary_logloss: 0.540962
# [323]	valid_0's binary_logloss: 0.54087
# [324]	valid_0's binary_logloss: 0.540759
# [325]	valid_0's binary_logloss: 0.540649
# [326]	valid_0's binary_logloss: 0.540541
# [327]	valid_0's binary_logloss: 0.540389
# [328]	valid_0's binary_logloss: 0.540324
# [329]	valid_0's binary_logloss: 0.540244
# [330]	valid_0's binary_logloss: 0.540129
# [331]	valid_0's binary_logloss: 0.540037
# [332]	valid_0's binary_logloss: 0.539924
# [333]	valid_0's binary_logloss: 0.53981
# [334]	valid_0's binary_logloss: 0.539731
# [335]	valid_0's binary_logloss: 0.539659
# [336]	valid_0's binary_logloss: 0.539533
# [337]	valid_0's binary_logloss: 0.539448
# [338]	valid_0's binary_logloss: 0.539349
# [339]	valid_0's binary_logloss: 0.539228
# [340]	valid_0's binary_logloss: 0.539146
# [341]	valid_0's binary_logloss: 0.539049
# [342]	valid_0's binary_logloss: 0.538951
# [343]	valid_0's binary_logloss: 0.538841
# [344]	valid_0's binary_logloss: 0.538758
# [345]	valid_0's binary_logloss: 0.538622
# [346]	valid_0's binary_logloss: 0.53854
# [347]	valid_0's binary_logloss: 0.538462
# [348]	valid_0's binary_logloss: 0.538354
# [349]	valid_0's binary_logloss: 0.538213
# [350]	valid_0's binary_logloss: 0.538118
# [351]	valid_0's binary_logloss: 0.537986
# [352]	valid_0's binary_logloss: 0.537847
# [353]	valid_0's binary_logloss: 0.537764
# [354]	valid_0's binary_logloss: 0.537687
# [355]	valid_0's binary_logloss: 0.537554
# [356]	valid_0's binary_logloss: 0.53748
# [357]	valid_0's binary_logloss: 0.537354
# [358]	valid_0's binary_logloss: 0.537277
# [359]	valid_0's binary_logloss: 0.537192
# [360]	valid_0's binary_logloss: 0.537057
# [361]	valid_0's binary_logloss: 0.536954
# [362]	valid_0's binary_logloss: 0.536875
# [363]	valid_0's binary_logloss: 0.536768
# [364]	valid_0's binary_logloss: 0.536694
# [365]	valid_0's binary_logloss: 0.536621
# [366]	valid_0's binary_logloss: 0.536519
# [367]	valid_0's binary_logloss: 0.536414
# [368]	valid_0's binary_logloss: 0.536337
# [369]	valid_0's binary_logloss: 0.536241
# [370]	valid_0's binary_logloss: 0.536148
# [371]	valid_0's binary_logloss: 0.536073
# [372]	valid_0's binary_logloss: 0.53595
# [373]	valid_0's binary_logloss: 0.535853
# [374]	valid_0's binary_logloss: 0.535797
# [375]	valid_0's binary_logloss: 0.535728
# [376]	valid_0's binary_logloss: 0.535639
# [377]	valid_0's binary_logloss: 0.535572
# [378]	valid_0's binary_logloss: 0.53552
# [379]	valid_0's binary_logloss: 0.535453
# [380]	valid_0's binary_logloss: 0.53537
# [381]	valid_0's binary_logloss: 0.535283
# [382]	valid_0's binary_logloss: 0.53516
# [383]	valid_0's binary_logloss: 0.535077
# [384]	valid_0's binary_logloss: 0.53496
# [385]	valid_0's binary_logloss: 0.534851
# [386]	valid_0's binary_logloss: 0.534764
# [387]	valid_0's binary_logloss: 0.534659
# [388]	valid_0's binary_logloss: 0.534604
# [389]	valid_0's binary_logloss: 0.534542
# [390]	valid_0's binary_logloss: 0.534462
# [391]	valid_0's binary_logloss: 0.534394
# [392]	valid_0's binary_logloss: 0.534284
# [393]	valid_0's binary_logloss: 0.534222
# [394]	valid_0's binary_logloss: 0.534156
# [395]	valid_0's binary_logloss: 0.534081
# [396]	valid_0's binary_logloss: 0.53403
# [397]	valid_0's binary_logloss: 0.533982
# [398]	valid_0's binary_logloss: 0.533882
# [399]	valid_0's binary_logloss: 0.533822
# [400]	valid_0's binary_logloss: 0.533771
# [401]	valid_0's binary_logloss: 0.533721
# [402]	valid_0's binary_logloss: 0.533646
# [403]	valid_0's binary_logloss: 0.533556
# [404]	valid_0's binary_logloss: 0.53346
# [405]	valid_0's binary_logloss: 0.533408
# [406]	valid_0's binary_logloss: 0.53333
# [407]	valid_0's binary_logloss: 0.53322
# [408]	valid_0's binary_logloss: 0.533154
# [409]	valid_0's binary_logloss: 0.533084
# [410]	valid_0's binary_logloss: 0.532982
# [411]	valid_0's binary_logloss: 0.53289
# [412]	valid_0's binary_logloss: 0.53284
# [413]	valid_0's binary_logloss: 0.532783
# [414]	valid_0's binary_logloss: 0.532689
# [415]	valid_0's binary_logloss: 0.532592
# [416]	valid_0's binary_logloss: 0.532548
# [417]	valid_0's binary_logloss: 0.532496
# [418]	valid_0's binary_logloss: 0.532445
# [419]	valid_0's binary_logloss: 0.532382
# [420]	valid_0's binary_logloss: 0.53232
# [421]	valid_0's binary_logloss: 0.532259
# [422]	valid_0's binary_logloss: 0.532181
# [423]	valid_0's binary_logloss: 0.532107
# [424]	valid_0's binary_logloss: 0.532003
# [425]	valid_0's binary_logloss: 0.53191
# [426]	valid_0's binary_logloss: 0.531856
# [427]	valid_0's binary_logloss: 0.531808
# [428]	valid_0's binary_logloss: 0.531717
# [429]	valid_0's binary_logloss: 0.531665
# [430]	valid_0's binary_logloss: 0.531561
# [431]	valid_0's binary_logloss: 0.531515
# [432]	valid_0's binary_logloss: 0.531463
# [433]	valid_0's binary_logloss: 0.531356
# [434]	valid_0's binary_logloss: 0.531297
# [435]	valid_0's binary_logloss: 0.531232
# [436]	valid_0's binary_logloss: 0.531172
# [437]	valid_0's binary_logloss: 0.531127
# [438]	valid_0's binary_logloss: 0.531075
# [439]	valid_0's binary_logloss: 0.531017
# [440]	valid_0's binary_logloss: 0.530969
# [441]	valid_0's binary_logloss: 0.530865
# [442]	valid_0's binary_logloss: 0.530809
# [443]	valid_0's binary_logloss: 0.53068
# [444]	valid_0's binary_logloss: 0.530628
# [445]	valid_0's binary_logloss: 0.530576
# [446]	valid_0's binary_logloss: 0.530529
# [447]	valid_0's binary_logloss: 0.530476
# [448]	valid_0's binary_logloss: 0.530366
# [449]	valid_0's binary_logloss: 0.530324
# [450]	valid_0's binary_logloss: 0.53022
# [451]	valid_0's binary_logloss: 0.530143
# [452]	valid_0's binary_logloss: 0.530042
# [453]	valid_0's binary_logloss: 0.529997
# [454]	valid_0's binary_logloss: 0.529916
# [455]	valid_0's binary_logloss: 0.529847
# [456]	valid_0's binary_logloss: 0.529807
# [457]	valid_0's binary_logloss: 0.529738
# [458]	valid_0's binary_logloss: 0.529689
# [459]	valid_0's binary_logloss: 0.529645
# [460]	valid_0's binary_logloss: 0.5296
# [461]	valid_0's binary_logloss: 0.529502
# [I 2021-12-12 18:08:15,887] Trial 19 finished with value: 0.5328984738477942 and parameters: {'device_type': 'gpu', 'max_depth': 9, 'num_leaves': 2720, 'min_data_in_leaf': 3600, 'learning_rate': 0.011612212124944205, 'n_estimators': 500, 'lambda_l1': 25, 'lambda_l2': 40, 'min_gain_to_split': 2.9894426838370376}. Best is trial 13 with value: 0.4916794108004551.
# [462]	valid_0's binary_logloss: 0.529424
# [463]	valid_0's binary_logloss: 0.529357
# [464]	valid_0's binary_logloss: 0.529291
# [465]	valid_0's binary_logloss: 0.529203
# [466]	valid_0's binary_logloss: 0.529149
# [467]	valid_0's binary_logloss: 0.529085
# [468]	valid_0's binary_logloss: 0.528989
# [469]	valid_0's binary_logloss: 0.528951
# [470]	valid_0's binary_logloss: 0.528904
# [471]	valid_0's binary_logloss: 0.52885
# [472]	valid_0's binary_logloss: 0.528809
# [473]	valid_0's binary_logloss: 0.528739
# [474]	valid_0's binary_logloss: 0.528647
# [475]	valid_0's binary_logloss: 0.528561
# [476]	valid_0's binary_logloss: 0.528482
# [477]	valid_0's binary_logloss: 0.528438
# [478]	valid_0's binary_logloss: 0.528377
# [479]	valid_0's binary_logloss: 0.528299
# [480]	valid_0's binary_logloss: 0.528215
# [481]	valid_0's binary_logloss: 0.528158
# [482]	valid_0's binary_logloss: 0.528098
# [483]	valid_0's binary_logloss: 0.528063
# [484]	valid_0's binary_logloss: 0.527989
# [485]	valid_0's binary_logloss: 0.527921
# [486]	valid_0's binary_logloss: 0.527845
# [487]	valid_0's binary_logloss: 0.527789
# [488]	valid_0's binary_logloss: 0.527743
# [489]	valid_0's binary_logloss: 0.527709
# [490]	valid_0's binary_logloss: 0.52762
# [491]	valid_0's binary_logloss: 0.527548
# [492]	valid_0's binary_logloss: 0.527508
# [493]	valid_0's binary_logloss: 0.52747
# [494]	valid_0's binary_logloss: 0.527412
# [495]	valid_0's binary_logloss: 0.527325
# [496]	valid_0's binary_logloss: 0.52729
# [497]	valid_0's binary_logloss: 0.527204
# [498]	valid_0's binary_logloss: 0.52715
# [499]	valid_0's binary_logloss: 0.527067
# [500]	valid_0's binary_logloss: 0.527022

# %%
study_summary(study)
# Out:
# Study:  lgbm_split
#
# Number of finished trials: 20
# Best trial:
#   Validation score: 0.4916794108004551
#   Params:
#     device_type: gpu
#     max_depth: 12
#     num_leaves: 2520
#     min_data_in_leaf: 300
#     learning_rate: 0.2011884316999342
#     n_estimators: 500
#     lambda_l1: 30
#     lambda_l2: 35
#     min_gain_to_split: 2.7591039026962063

# %%
# pass the optuna best parameters as hyperparameters
best_clf = train_best_lgbm(projected_train, study.best_params)

# %%
best_clf.__dict__
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 2520,
#  'max_depth': 12,
#  'learning_rate': 0.2011884316999342,
#  'n_estimators': 500,
#  'subsample_for_bin': 200000,
#  'min_split_gain': 0.0,
#  'min_child_weight': 0.001,
#  'min_child_samples': 20,
#  'subsample': 1.0,
#  'subsample_freq': 0,
#  'colsample_bytree': 1.0,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'random_state': None,
#  'n_jobs': -1,
#  'silent': 'warn',
#  'importance_type': 'split',
#  '_Booster': <lightgbm.basic.Booster at 0x1e36012d520>,
#  '_evals_result': None,
#  '_best_score': defaultdict(collections.OrderedDict, {}),
#  '_best_iteration': None,
#  '_other_params': {'device_type': 'gpu',
#   'min_data_in_leaf': 300,
#   'lambda_l1': 30,
#   'lambda_l2': 35,
#   'min_gain_to_split': 2.7591039026962063},
#  '_objective': 'binary',
#  'class_weight': None,
#  '_class_weight': None,
#  '_class_map': {0.0: 0, 1.0: 1},
#  '_n_features': 20,
#  '_n_features_in': 20,
#  '_classes': array([0., 1.]),
#  '_n_classes': 2,
#  'device_type': 'gpu',
#  'min_data_in_leaf': 300,
#  'lambda_l1': 30,
#  'lambda_l2': 35,
#  'min_gain_to_split': 2.7591039026962063,
#  '_le': LabelEncoder(),
#  '_fobj': None,
#  'fitted_': True}

# %%
def standard_scaling(train_df, test_df):
    standard_scaler = StandardScaler()
    feature_cols = [col for col in train_df.columns if col != "LABELS"]
    
    train_df[feature_cols] = standard_scaler.fit_transform(train_df[feature_cols])
    test_df[feature_cols] = standard_scaler.transform(test_df[feature_cols])

    return train_df, test_df

# %%
agg_test = agg_over_months(test_df, freq=3)
scaled_train, scaled_test = standard_scaling(agg_train, agg_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4224/3958747982.py in <module>
#       1 agg_test = agg_over_months(test_df, freq=3)
# ----> 2 scaled_train, scaled_test = standard_scaling(agg_train, agg_test)
#
# ~\AppData\Local\Temp/ipykernel_4224/1060838705.py in standard_scaling(train_df, test_df)
#       4
#       5     train_df[feature_cols] = standard_scaler.fit_transform(train_df[feature_cols])
# ----> 6     test_df[feature_cols] = standard_scaler.transform(test_df[feature_cols])
#       7
#       8     return train_df, test_df
#
# ~\miniconda3\envs\kaggle2\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\miniconda3\envs\kaggle2\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\miniconda3\envs\kaggle2\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['NDVI_06_mean', 'NDVI_612_mean', 'S2_B4_06_mean', 'S2_B4_612_mean',\n       'S2_B2_06_mean', 'S2_B2_612_mean', 'S2_B12_06_mean', 'S2_B12_612_mean',\n       'ERA5_total_precipitation_06_mean', 'ERA5_total_precipitation_612_mean',\n       'topo_elevation_06_mean', 'topo_elevation_612_mean', 'S2_B11_06_mean',\n       'S2_B11_612_mean', 'S2_B9_06_mean', 'S2_B9_612_mean', 'S1_VV_06_mean',\n       'S1_VV_612_mean', 'S1_VH_06_mean', 'S1_VH_612_mean', 'S2_B6_06_mean',\n       'S2_B6_612_mean', 'S2_B7_06_mean', 'S2_B7_612_mean',\n       'ERA5_temperature_2m_06_mean', 'ERA5_temperature_2m_612_mean',\n       'topo_slope_06_mean', 'topo_slope_612_mean', 'S2_B5_06_mean',\n       'S2_B5_612_mean', 'S2_B8A_06_mean', 'S2_B8A_612_mean', 'S2_B3_06_mean',\n       'S2_B3_612_mean', 'S2_B8_06_mean', 'S2_B8_612_mean'],\n      dtype='object')] are in the [columns]"

# %%
preds = best_clf.predict(agg_test)

# %% [markdown]
# # Save prediction

# %%
save_pred(projected_test, preds, "7")
